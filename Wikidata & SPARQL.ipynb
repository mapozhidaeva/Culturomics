# %%
import requests
import pandas as pd
from collections import OrderedDict

#здесь 3 запроса SPARQL к Викиданным, которые выдают список списков с высказываниями с датами. 
#один общий запрос, скорее всего, невозможен, поскольку одной строке в табличке (=одному высказыванию) 
#может соответствовать только одна дата (или две - если это дата начала и дата окончания чего-то).
#если в одном высказывании будет много дат, то будет трудно разобраться, что к чему


#http://tinyurl.com/y9m738lr  - простые триплеты с датой
def query_for_simple_triplets(q_numbers):
    
    url = "https://query.wikidata.org/sparql"
    
    query = """SELECT ?itemLabel ?propertyLabel ?date
    WHERE
    {
      VALUES (?item) {(wd:Q???)}
  
      # ?item ?predicate ?date. 
      FILTER(DATATYPE(?date) = xsd:dateTime).
      MINUS { ?item schema:dateModified ?date. }
      MINUS { ?item wikibase:timestamp ?date. }
  
      BIND( IRI(REPLACE( STR(?predicate),"prop/direct/","entity/" )) AS ?property). 
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ru". }
    }
    ORDER BY ?item ?date
    """
        
    query = query.replace('(wd:Q???)',q_numbers)
    r = requests.get(url, params = {'format': 'json', 'query': query})
    data = r.json()
    
    lst = []
    if data != None:
        for item in data['results']['bindings']:
            lst.append([item['itemLabel']['value'], 
                        item['propertyLabel']['value'], 
                        str(item['date']['value'])[:-10]]) #"обрезание" даты. потом вставлю регулярку
    return lst


#http://tinyurl.com/yboysd2z  - start time-end time
def query_for_starttime_endtime(q_numbers):
    
    url = "https://query.wikidata.org/sparql"
    
    query = """SELECT ?itemLabel ?propertyLabel ?objectLabel ?organizationLabel ?starttime 
    # ?endtime
    WHERE {
      VALUES (?item) {(wd:Q???)}
  
      # ?item ?predicate ?statement .  
      # ?statement ?ps ?object. 
      OPTIONAL {?statement pq:P642 ?organization}.
      # ?statement pq:P580 ?starttime.
      OPTIONAL {?statement pq:P582 ?endtime}. 
   
      # ?property wikibase:statementProperty ?ps .
  
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ru" }
    }
    ORDER BY ?itemLabel ?propertyLabel
    """
    
    query = query.replace('(wd:Q???)',q_numbers)
    r = requests.get(url, params = {'format': 'json', 'query': query})
    data = r.json()
    
    lst = []
    for item in data['results']['bindings']:    
        lst.append([item['itemLabel']['value'], 
                    item['propertyLabel']['value'],
                    item['objectLabel']['value'],
                    item['organizationLabel']['value'] if 'organizationLabel' in item else '',
                    str(item['starttime']['value'])[:-10],
                    str(item['endtime']['value'])[:-10]] if 'endtime' in item else '')

    return lst


#http://tinyurl.com/y947qncg  -　point in time
def query_for_point_in_time(q_numbers):
    
    url = "https://query.wikidata.org/sparql"
    
    query = """SELECT ?itemLabel ?propertyLabel ?objectLabel ?organizationLabel ?point_in_time
    WHERE {
      VALUES (?item) {(wd:Q???)}
  
      # ?item ?predicate ?statement .  
      # ?statement ?ps ?object. 
      OPTIONAL {?statement pq:P642 ?organization}.
      # ?statement pq:P585 ?point_in_time.
   
      # ?property wikibase:statementProperty ?ps .
  
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ru" }
    }
    ORDER BY ?itemLabel ?propertyLabel
    """
    
    query = query.replace('(wd:Q???)',q_numbers)
    r = requests.get(url, params = {'format': 'json', 'query': query})
    data = r.json()
    
    lst = []
    for item in data['results']['bindings']:    
        lst.append([item['itemLabel']['value'], 
                    item['propertyLabel']['value'],
                    item['objectLabel']['value'],
                    item['organizationLabel']['value'] if 'organizationLabel' in item else '',
                    str(item['point_in_time']['value'])[:-10]])

    return lst

q_numbers = '(wd:Q635)(wd:Q7747)(wd:Q243)'#здесь должны быть номера объектов из наших n-грамм
#в Викиданных, которые мы подставляем в запрос

dates_list = query_for_simple_triplets(q_numbers) + query_for_starttime_endtime(q_numbers) + query_for_point_in_time(q_numbers)
for i in dates_list:
    if i != '':
        print(i)
# Out:
# ['Эйфелева башня', 'дата основания/создания/возникновения', '1887-01-01']
# ['Эйфелева башня', 'дата официального открытия', '1889-03-31']
# ['Эйфелева башня', 'дата перехода в общественное достояние', '1993-01-01']
# ['Клеопатра', 'дата рождения', '-068-01-01']
# ['Клеопатра', 'дата смерти', '-029-08-10']
# ['Владимир Владимирович Путин', 'дата рождения', '1952-10-07']
# ['Владимир Владимирович Путин', 'вид или род войск', 'Комитет государственной безопасности СССР', '', '1975-01-01', '1991-01-01']
# ['Владимир Владимирович Путин', 'владеет', 'ядерный чемоданчик (Россия)', '', '1999-12-31', '2008-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'председатель Правительства Российской Федерации', '', '1999-08-16', '2000-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'руководство ФСБ России', '', '1998-07-25', '1999-03-29']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'Временное исполнение полномочий президента России', '', '1999-12-31', '2000-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'секретарь Совета безопасности Российской Федерации', '', '1999-03-29', '1999-08-09']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'председатель Совета глав государств СНГ', '', '2000-01-25', '2003-01-29']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'председатель Совета глав государств СНГ', '', '2017-01-01', '2017-12-31']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'Президент Российской Федерации', '', '2000-05-07', '2008-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'председатель Правительства Российской Федерации', '', '2008-05-08', '2012-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'председатель Совета глав государств СНГ', '', '2004-09-16', '2006-05-20']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'председатель', 'Наш дом — Россия', '1995-01-01', '1997-01-01']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'Верховный Главнокомандующий Вооружёнными Силами Российской Федерации', '', '1999-12-31', '2008-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'Временное исполнение полномочий президента России', '', '1999-12-31', '2000-05-07']
# ['Владимир Владимирович Путин', 'место жительства', 'Дрезден', '', '1985-01-01', '1990-01-01']
# ['Владимир Владимирович Путин', 'место жительства', 'Басков переулок', '', '1952-01-01', '1980-01-01']
# ['Владимир Владимирович Путин', 'место жительства', 'Санкт-Петербург', '', '1987-01-01', '1992-01-01']
# ['Владимир Владимирович Путин', 'питомец', 'Конни Полгрейв', '', '1999-01-01', '2014-01-01']
# ['Владимир Владимирович Путин', 'работодатель', 'Управление делами Президента Российской Федерации', '', '1996-08-01', '1997-03-01']
# ['Владимир Владимирович Путин', 'супруг(а)', 'Людмила Александровна Путина', '', '1983-07-28', '2014-04-02']
# ['Владимир Владимирович Путин', 'участвовал в', 'Вторая чеченская война', '', '1999-12-31', '2008-05-07']
# ['Владимир Владимирович Путин', 'учебное заведение', 'Школа № 281', '', '1968-01-01', '1970-01-01']
# ['Владимир Владимирович Путин', 'учебное заведение', 'юридический факультет СПбГУ', '', '1970-01-01', '1975-01-01']
01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Республики Сербии', '', '2013-02-25']
# ['Владимир Владимирович Путин', 'полученные награды', 'Человек года по версии журнала «Time»', '', '2007-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Славы и Чести', '', '2007-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Заида', '', '2007-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден святого равноапостольного великого князя Владимира', '', '2002-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'рейтинг самых влиятельных людей мира по версии Forbes', '', '2014-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'рейтинг самых влиятельных людей мира по версии Forbes', '', '2013-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден «За заслуги перед Республикой Дагестан»', '', '2014-09-13']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Святого Саввы', '', '2011-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'Памятная медаль А. М. Горчакова', '', '2001-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'премия мира имени Конфуция', '', '2011-11-15']
# ['Владимир Владимирович Путин', 'полученные награды', 'рейтинг самых влиятельных людей мира по версии Forbes', '', '2016-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Хо Ши Мина', '', '2001-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'медаль «Участнику марш-броска 12 июня 1999 г. Босния — Косово»', '', '2000-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'медаль «За заслуги перед Национальной народной армией ГДР»', '', '1988-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Почёта', '', '1996-03-12']
# ['Владимир Владимирович Путин', 'полученные награды', 'именное огнестрельное оружие', '', '2010-10-27']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Хосе Марти', '', '2014-07-11']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Дружбы народов', '', '2013-03-15']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Исмоили Сомони', '', '2007-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'Закрытая устрица', '', '2007-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'Большой крест ордена Святого Карла', '', '2013-10-04']
# ['Владимир Владимирович Путин', 'полученные награды', 'заслуженный тренер', '', '2006-01-01']
# ['Владимир Владимирович Путин', 'полученные награды', 'орден Дружбы', '', '2018-06-08']
# ['Владимир Владимирович Путин', 'род занятий', 'каскадёр', '', '1970-01-01']
# ['Владимир Владимирович Путин', 'участвовал в', '30-й саммит G8', '', '2004-06-01']
# ['Владимир Владимирович Путин', 'участвовал в', 'Петербургский международный экономический форум', '', '2016-06-17']
# ['Владимир Владимирович Путин', 'участвовал в', 'Общие дебаты 70-й сессии Генеральной ассамблеи ООН', '', '2015-09-28']
# ['Владимир Владимирович Путин', 'участвовал в', 'Президентские выборы в России в 2012 году', '', '2012-03-04']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2001-12-24']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2002-12-19']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2003-12-18']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2005-09-27']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2006-10-25']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2007-10-18']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2013-04-25']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2015-04-16']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным', '', '2016-04-14']
# ['Владимир Владимирович Путин', 'участвовал в', 'Саммит ОДКБ', '', '2013-09-23']
# ['Владимир Владимирович Путин', 'участвовал в', 'Саммит ОДКБ', '', '2014-12-23']
# ['Владимир Владимирович Путин', 'участвовал в', 'Саммит ОДКБ', '', '2015-09-15']
# ['Владимир Владимирович Путин', 'участвовал в', 'Саммит ОДКБ', '', '2015-12-21']
# ['Владимир Владимирович Путин', 'участвовал в', 'Саммит ОДКБ', '', '2016-10-14']
# ['Владимир Владимирович Путин', 'участвовал в', 'Саммит ОДКБ', '', '2016-12-26']
# ['Владимир Владимирович Путин', 'участвовал в', '39-й саммит G8', '', '2013-06-01']
# ['Владимир Владимирович Путин', 'участвовал в', 'Церемония открытия зимних Олимпийских игр 2014', '', '2014-02-07']
# ['Владимир Владимирович Путин', 'участвовал в', '31-й саммит G8', '', '2005-07-01']
# ['Владимир Владимирович Путин', 'участвовал в', '33-й саммит G8', '', '2007-06-01']
# ['Владимир Владимирович Путин', 'участвовал в', 'Президентские выборы в России в 2004 году', '', '2004-03-14']
# ['Владимир Владимирович Путин', 'участвовал в', 'Прямая линия с Владимиром Путиным (2014)', '', '2014-04-17']
# ['Владимир Владимирович Путин', 'участвовал в', 'Восточный экономический форум', '', '2015-09-04']
# ['Владимир Владимирович Путин', 'участвовал в', 'Восточный экономический форум', '', '2016-09-03']
# ['Владимир Владимирович Путин', 'участвовал в', 'Восточный экономический форум', '', '2017-09-05']
# ['Владимир Владимирович Путин', 'участвовал в', '29-й саммит G8', '', '2003-06-01']
# ['Владимир Владимирович Путин', 'участвовал в', '27-й саммит G8', '', '2001-07-01']
# ['Владимир Владимирович Путин', 'участвовал в', '
01']
# ['Владимир Владимирович Путин', 'участвовал в', 'ежегодная большая пресс-конференция Президента России Владимира Путина', '', '2008-02-14']
# ['Владимир Владимирович Путин', 'участвовал в', 'ежегодная большая пресс-конференция Президента России Владимира Путина', '', '2016-12-23']
# ['Владимир Владимирович Путин', 'участвовал в', '28-й саммит G8', '', '2002-06-01']
# ['Владимир Владимирович Путин', 'участвовал в', '119-я сессия МОК', '', '2007-07-04']
# ['Владимир Владимирович Путин', 'участвовал в', 'Совет при Президенте Российской Федерации по развитию гражданского общества и правам человека', '', '2005-07-20']
# ['Владимир Владимирович Путин', 'участвовал в', 'Совет при Президенте Российской Федерации по развитию гражданского общества и правам человека', '', '2007-01-11']
# ['Владимир Владимирович Путин', 'учёная степень', 'кандидат экономических наук', '', '1997-01-01']

# %%
#примерно так по году можно выбирать только релевантные высказывания
date = '1999'
for statement in dates_list:
    if statement != '' and (statement[-1].startswith(date) or statement[-2].startswith(date)): 
        print(statement)
# Out:
# ['Владимир Владимирович Путин', 'владеет', 'ядерный чемоданчик (Россия)', '', '1999-12-31', '2008-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'председатель Правительства Российской Федерации', '', '1999-08-16', '2000-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'руководство ФСБ России', '', '1998-07-25', '1999-03-29']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'Временное исполнение полномочий президента России', '', '1999-12-31', '2000-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'секретарь Совета безопасности Российской Федерации', '', '1999-03-29', '1999-08-09']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'Верховный Главнокомандующий Вооружёнными Силами Российской Федерации', '', '1999-12-31', '2008-05-07']
# ['Владимир Владимирович Путин', 'занимаемая должность', 'Временное исполнение полномочий президента России', '', '1999-12-31', '2000-05-07']
# ['Владимир Владимирович Путин', 'питомец', 'Конни Полгрейв', '', '1999-01-01', '2014-01-01']
# ['Владимир Владимирович Путин', 'участвовал в', 'Вторая чеченская война', '', '1999-12-31', '2008-05-07']
# ['Владимир Владимирович Путин', 'член политической партии', 'Наш дом — Россия', '', '1995-05-01', '1999-01-01']
# ['Владимир Владимирович Путин', 'воинское звание', 'полковник', '', '1999-01-01']
# ['Владимир Владимирович Путин', 'участвовал в', 'Новогоднее обращение к народу', '', '1999-12-31']

# %%
#потом потестирую формат вывода датафрейм. пока обычные списки кажутся удобнее
#это результат запроса простых триплетов с датами

url = "https://query.wikidata.org/sparql"
    
query = """SELECT ?itemLabel ?propertyLabel ?date
    WHERE
    {
      VALUES (?item) {(wd:Q???)}
  
      # ?item ?predicate ?date. 
      FILTER(DATATYPE(?date) = xsd:dateTime).
      MINUS { ?item schema:dateModified ?date. }
      MINUS { ?item wikibase:timestamp ?date. }
  
      BIND( IRI(REPLACE( STR(?predicate),"prop/direct/","entity/" )) AS ?property). 
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ru". }
    }
    ORDER BY ?item ?date
    """

q_numbers = '(wd:Q635)(wd:Q7747)(wd:Q243)'
query = query.replace('(wd:Q???)',q_numbers)
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()
    
for item in data['results']['bindings']:
    dates.append(OrderedDict({
        'item': item['itemLabel']['value'],
        'property': item['propertyLabel']['value'],
        'date': str(item['date']['value'])[:-10]})) 

df = pd.DataFrame(dates)
df.set_index('item', inplace=True)
df = df.astype({'property': str, 'date': str})
df.head()
# Out:
#                                               property        date
# item
# Эйфелева башня   дата основания/создания/возникновения  1887-01-01
# Эйфелева башня              дата официального открытия  1889-03-31
# Эйфелева башня  дата перехода в общественное достояние  1993-01-01
# Клеопатра                                дата рождения  -068-01-01
# Клеопатра                                  дата смерти  -029-08-10
