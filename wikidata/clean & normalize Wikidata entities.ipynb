# %% [markdown]
# # Обработка сущностей из Викиданных и создание словарей

# %%
def read_tsv(file):
    with open(file, "r") as f:
        f = f.readlines()
    data = []
    for line in f:
        line = line.strip('\n')
        q, entity, aliases = line.split('\t')
        data.append([q, entity, aliases])
    return data

# %% [markdown]
# Читаем tsv-файл, в котором собраны сущности из русскоязычной версии Викиданных, их уникальные идентификаторы Q и другие возможные наименования.

# %%
# %%time
data = read_tsv("/Users/anyway/Desktop/all-entities-bigfile.tsv")
# Out:
# CPU times: user 40.6 s, sys: 2min 14s, total: 2min 55s
# Wall time: 6min 10s

# %%
len(data)
# Out:
# 5837666

# %%
data[1226]
# Out:
# ['Q11349', 'туманность Орёл', 'M 16|NGC 6611']

# %%
# %%time
import re


#чистим Викиданные
def clean_wikidata(data):
    russian = "[А-Яа-я]+"
    prefixes = ("Категория:", "Шаблон:", "Приложение:", "ВЭ /", "БЭАН /", "ЭСБЕ /", "РБС /", "БЭЮ /", "ЭЛ /", 
                "МЭСБЕ /", "ЕЭБЕ /", "ТСД /", "ТСД2 /", "ПБЭ /", "БСЭ1 /", "НЭС /", "ББСРП /", "РСКД /", "ТСД3 /") 
    data = [i for i in data if len(i[1]) > 2 
            and re.search(russian, i[1]) 
            and not i[1].startswith(prefixes)]
    for indx, line in enumerate(data):
        aliases = line[2].split('|')
        data[indx][2] = " | ".join([i for i in aliases if re.search(russian, i)])
    with open('clean-russian-wikidata.tsv', 'w') as f:
        for i in data:
            f.write("\t".join(i) + '\n')
    return data

clean_data = clean_wikidata(data)    
len(clean_data)
# Out:
# CPU times: user 19.2 s, sys: 4.5 s, total: 23.7 s
# Wall time: 24.9 s

# %%
print(len(clean_data))
clean_data[:100]
# Out:
# 2234352
# [['Q31', 'Бельгия', 'Королевство Бельгия'],
#  ['Q8', 'счастье', ''],
#  ['Q23', 'Джордж Вашингтон', 'Вашингтон, Джордж'],
#  ['Q24', 'Джек Бауэр', ''],
#  ['Q42', 'Дуглас Адамс', 'Адамс, Дуглас'],
#  ['Q1868', 'Поль Отле', 'Отле, Поль'],
#  ['Q2013', 'Викиданные', 'Викидата'],
#  ['Q45', 'Португалия', 'Португальская Республика'],
#  ['Q51', 'Антарктида', ''],
#  ['Q58', 'пенис', 'детородный орган | половой член | член'],
#  ['Q68', 'компьютер', ''],
#  ['Q75', 'Интернет', ''],
#  ['Q125', 'ноябрь', 'ноября'],
#  ['Q140', 'лев', ''],
#  ['Q144', 'собака', 'собака обыкновенная'],
#  ['Q147', 'котёнок', 'Котёнок | Котенок'],
#  ['Q148', 'Китайская Народная Республика', 'КНР | Китай | Поднебесная'],
#  ['Q155', 'Бразилия', 'Федеративная Республика Бразилия'],
#  ['Q163', 'Йоркшир', ''],
#  ['Q177', 'пицца', ''],
#  ['Q178', 'макаронные изделия', 'паста | макароны'],
#  ['Q183', 'Германия', 'Федеративная Республика Германия | ФРГ | Дойчланд'],
#  ['Q207', 'Джордж Уокер Буш', 'Джордж Буш - младший | Джордж Буш-младший'],
#  ['Q210', 'прямой угол', ''],
#  ['Q233', 'Мальта', 'Республика Мальта'],
#  ['Q288', 'Тур', ''],
#  ['Q297', 'Диего Веласкес', 'Веласкес, Диего'],
#  ['Q298', 'Чили', 'Республика Чили'],
#  ['Q317', 'диктатура', ''],
#  ['Q328', 'английская Википедия', 'англовики | енвики | ен-вики'],
#  ['Q362',
#   'Вторая мировая война',
#   '2 мировая война | II мировая война | Вторая мировая | ВМВ | 2-я мировая война | Итоги и последствия Второй мировой войны | Вторая Мировая война | ВМв'],
#  ['Q368',
#   'Аугусто Пиночет',
#   'Аугусто Хосе Рамон Пиночет Угарт | Пиночет | Пиночет, Аугусто'],
#  ['Q398', 'Бахрейн', 'Королевство Бахрейн'],
#  ['Q411', 'астробиология', ''],
#  ['Q412', 'пластинки «Пионера»', ''],
#  ['Q431', 'зоология', ''],
#  ['Q433', 'Курув', ''],
#  ['Q443', 'Я — берлинец', ''],
#  ['Q447', 'Энциклопедия, или Толковый словарь наук, искусств и ремёсел', ''],
#  ['Q463', 'Рона — Альпы', 'Рона-Альпы'],
#  ['Q497', 'анус', 'задний проход'],
#  ['Q501', 'Шарль Бодлер', 'Бодлер, Шарль'],
#  ['Q506', 'цветок', 'цветы'],
#  ['Q511', 'Лионский музей изобразительных искусств', ''],
#  ['Q514', 'анатомия', ''],
#  ['Q524', 'Везувий', ''],
#  ['Q544', 'Солнечная система', ''],
#  ['Q550', 'Елисейские Поля', 'Шанз-Элизе'],
#  ['Q556', 'водород', ''],
#  ['Q585', 'Осло', ''],
#  ['Q586', 'Бонн', ''],
#  ['Q587', 'Собор всех святых', 'Петровское заговенье'],
#  ['Q597', 'Лиссабон', 'Лисбоа | Лишбоа'],
#  ['Q616', 'Божоле', ''],
#  ['Q619', 'Николай Коперник', ''],
#  ['Q633', 'Нил Янг', 'Нил Персивэл Янг'],
#  ['Q634', 'планета', ''],
#  ['Q647', 'Ренн', ''],
#  ['Q648', 'Лилль', ''],
#  ['Q659', 'север', ''],
#  ['Q661', 'гидротаранный насос', 'гидравлический таран'],
#  ['Q676', 'проза', 'прозаическое произведение'],
#  ['Q686', 'Вануату', 'Республика Вануату'],
#  ['Q688', 'хлор', ''],
#  ['Q694', 'Южная Голландия', ''],
#  ['Q716', 'титан', ''],
#  ['Q722', 'ванадий', ''],
#  ['Q732', 'Франкезинья', ''],
#  ['Q746', 'крок-мадам', 'Крок-мадам'],
#  ['Q747', 'Пьер Корнель', ''],
#  ['Q749', 'Гронинген', ''],
#  ['Q764', 'грибы', ''],
#  ['Q771', 'Массачусетс', ''],
#  ['Q801', 'Израиль', 'Государство Израиль'],
#  ['Q807', 'Лозанна', ''],
#  ['Q815', 'Габриель Гонсалес Видела', ''],
#  ['Q819', 'Лаос', 'Лаосская Народно-Демократическая Республика'],
#  ['Q844', 'Джеймс Бонд', 'агент 007'],
#  ['Q853', 'Андрей Арсеньевич Тарковский', 'Андре́й Арсе́ньевич Тарко́вский'],
#  ['Q859', 'Платон', ''],
#  ['Q863', 'Таджикистан', 'Республика Таджикистан'],
#  ['Q869', 'Таиланд', 'Королевство Таиланд'],
#  ['Q873', 'Мерил Стрип', 'Мэри Луиз «Мерил» Стрип'],
#  ['Q878', 'Объединённые Арабские Эмираты', 'ОАЭ | Эмираты'],
#  ['Q880', 'платина', ''],
#  ['Q883',
#   'Новосибирск',
#   'Ново-Николаевск | Александровский | Ново-Николаевский | Новосиби́рск | Новониколаевск'],
#  ['Q891',
#   'Нижний Новгород',
#   'Горький | Карман России | Столица Поволжья | Нижний'],
#  ['Q898', 'Омск', ''],
#  ['Q899', 'Суэцкий канал', ''],
#  ['Q901', 'учёный', 'научный работник'],
#  ['Q903', 'Эрта Але', ''],
#  ['Q907', 'Гордон Фримен', ''],
#  ['Q912', 'Мали', 'Республика Мали'],
#  ['Q916', 'Ангола', 'Республика Ангола'],
#  ['Q922', 'Брач', ''],
#  ['Q943', 'жёлтый', 'жёлтый цвет'],
#  ['Q946', 'Дональд Туск', 'Дональд Францишек Туск'],
#  ['Q951', 'ориентирование туалетной бумаги', ''],
#  ['Q952', 'Реджоло', ''],
#  ['Q957', 'список списков списков', '']]

# %%
# %%time

from pymorphy2 import MorphAnalyzer
from string import punctuation

punct = punctuation+'«»—…“”*–'
morph = MorphAnalyzer()

#лемматизируем Викиданные и почистим от лишней полнктуации
def normalize(data):
    norm_data = []
    for line in data:
        entity = [word.strip(punct) for word in line[1].lower().split()]
        entity = [morph.parse(word)[0].normal_form for word in entity if word]
        aliases = line[2].lower()
        if aliases != '':
            if ' | ' in aliases:
                aliases = [alias.split() for alias in aliases.split(" | ")]
                aliases = [[morph.parse(word.strip(punct))[0].normal_form for word in alias if word] 
                           for alias in aliases]
                norm_data.append([line[0], [entity] + aliases])
            else:
                aliases = [word.strip(punct) for word in aliases.split()]
                aliases = [morph.parse(word)[0].normal_form for word in aliases if word]
                norm_data.append([line[0], [entity] + [aliases]])     
        else:
            norm_data.append([line[0], entity])
    return norm_data

norm_data = normalize(clean_data[:100])
#заметила, что нужно еще добавить очистку от диакритиков
# Out:
# CPU times: user 154 ms, sys: 50 ms, total: 204 ms
# Wall time: 330 ms

# %%
from string import punctuation

punct = punctuation+'«»—…“”*–'
print(punct)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~«»—…“”*–

# %%
norm_data
# Out:
# [['Q31', [['бельгия'], ['королевство', 'бельгия']]],
#  ['Q8', ['счастие']],
#  ['Q23', [['джордж', 'вашингтон'], ['вашингтон', 'джордж']]],
#  ['Q24', ['джек', 'бауэр']],
#  ['Q42', [['дуглас', 'адамс'], ['адамс', 'дуглас']]],
#  ['Q1868', [['поль', 'отля'], ['отля', 'поль']]],
#  ['Q2013', [['викидать'], ['викидата']]],
#  ['Q45', [['португалия'], ['португальский', 'республика']]],
#  ['Q51', ['антарктида']],
#  ['Q58', [['пенис'], ['детородный', 'орган'], ['половый', 'член'], ['член']]],
#  ['Q68', ['компьютер']],
#  ['Q75', ['интернет']],
#  ['Q125', [['ноябрь'], ['ноябрь']]],
#  ['Q140', ['левый']],
#  ['Q144', [['собака'], ['собака', 'обыкновенный']]],
#  ['Q147', [['котёнок'], ['котёнок'], ['котёнок']]],
#  ['Q148',
#   [['китайский', 'народный', 'республика'],
#    ['кнр'],
#    ['китай'],
#    ['поднебесный']]],
#  ['Q155', [['бразилия'], ['федеративный', 'республика', 'бразилия']]],
#  ['Q163', ['йоркшир']],
#  ['Q177', ['пицца']],
#  ['Q178', [['макаронный', 'изделие'], ['паста'], ['макароны']]],
#  ['Q183',
#   [['германия'],
#    ['федеративный', 'республика', 'германия'],
#    ['фрг'],
#    ['дойчланда']]],
#  ['Q207',
#   [['джордж', 'уокер', 'буш'],
#    ['джордж', 'буш', '', 'младший'],
#    ['джордж', 'буш-младший']]],
#  ['Q210', ['прямая', 'угол']],
#  ['Q233', [['мальта'], ['республика', 'мальта']]],
#  ['Q288', ['тур']],
#  ['Q297', [['диего', 'веласкес'], ['веласкес', 'диего']]],
#  ['Q298', [['чили'], ['республика', 'чили']]],
#  ['Q317', ['диктатура']],
#  ['Q328',
#   [['английский', 'википедия'], ['англовик'], ['енвика'], ['ен-вика']]],
#  ['Q362',
#   [['два', 'мировой', 'война'],
#    ['2', 'мировой', 'война'],
#    ['ii', 'мировой', 'война'],
#    ['два', 'мировой'],
#    ['вмв'],
#    ['2-я', 'мировой', 'война'],
#    ['итог', 'и', 'последствие', 'два', 'мировой', 'война'],
#    ['два', 'мировой', 'война'],
#    ['вмв']]],
#  ['Q368',
#   [['аугусто', 'пиночет'],
#    ['аугусто', 'хосе', 'рамон', 'пиночет', 'угарт'],
#    ['пиночет'],
#    ['пиночет', 'аугусто']]],
#  ['Q398', [['бахрейн'], ['королевство', 'бахрейн']]],
#  ['Q411', ['астробиология']],
#  ['Q412', ['пластинка', 'пионер']],
#  ['Q431', ['зоология']],
#  ['Q433', ['куруть']],
#  ['Q443', ['я', 'берлинец']],
#  ['Q447',
#   ['энциклопедия',
#    'или',
#    'толковый',
#    'словарь',
#    'наука',
#    'искусство',
#    'и',
#    'ремесло']],
#  ['Q463', [['рон', 'альп'], ['рона-альп']]],
#  ['Q497', [['анус'], ['задний', 'проход']]],
#  ['Q501', [['шарль', 'бодлера'], ['бодлера', 'шарль']]],
#  ['Q506', [['цветок'], ['цвета']]],
#  ['Q511', ['лионский', 'музей', 'изобразительный', 'искусство']],
#  ['Q514', ['анатомия']],
#  ['Q524', ['везувий']],
#  ['Q544', ['солнечный', 'система']],
#  ['Q550', [['елисейский', 'поль'], ['шанз-элиза']]],
#  ['Q556', ['водород']],
#  ['Q585', ['осло']],
#  ['Q586', ['бонн']],
#  ['Q587', [['собор', 'весь', 'святой'], ['петровский', 'заговенье']]],
#  ['Q597', [['лиссабон'], ['лисбоа'], ['лишбоа']]],
#  ['Q616', ['божоля']],
#  ['Q619', ['николай', 'коперник']],
#  ['Q633', [['нил', 'янг'], ['нил', 'персивэл', 'янг']]],
#  ['Q634', ['планет']],
#  ['Q647', ['ренна']],
#  ['Q648', ['лилль']],
#  ['Q659', ['север']],
#  ['Q661', [['гидротаранный', 'насос'], ['гидравлический', 'таран']]],
#  ['Q676', [['проза'], ['прозаический', 'произведение']]],
#  ['Q686', [['вануату'], ['республика', 'вануату']]],
#  ['Q688', ['хлор']],
#  ['Q694', ['южный', 'голландия']],
#  ['Q716', ['титан']],
#  ['Q722', ['ванадий']],
#  ['Q732', ['франкезинья']],
#  ['Q746', [['крок-мадам'], ['крок-мадам']]],
#  ['Q747', ['пьер', 'корнель']],
#  ['Q749', ['гронинген']],
#  ['Q764', ['гриб']],
#  ['Q771', ['массачусетс']],
#  ['Q801', [['израиль'], ['государство', 'израиль']]],
#  ['Q807', ['лозанна']],
#  ['Q815', ['габриеля', 'гонсалес', 'видеть']],
#  ['Q819', [['лаос'], ['лаосский', 'народно-демократический', 'республика']]],
#  ['Q844', [['джеймс', 'бонд'], ['агент', '007']]],
#  ['Q853',
#   [['андрей', 'арсений', 'тарковский'],
#    ['андре́ть', 'арсе́ний', 'тарко́вский']]],
#  ['Q859', ['платон']],
#  ['Q863', [['таджикистан'], ['республика', 'таджикистан']]],
#  ['Q869', [['таиланд'], ['королевство', 'таиланд']]],
#  ['Q873', [['мерило', 'стрип'], ['мэри', 'луиз', 'мерило', 'стрип']]],
#  ['Q878', [['объединить', 'арабский', 'эмират'], ['оаэ'], ['эмират']]],
#  ['Q880', ['платина']],
#  ['Q883',
#   [['новосибирск'],
#    ['ново-николаевск'],
#    ['александровский'],
#    ['ново-николаевский'],
#    ['новосиби́рск'],
#    ['новониколаевск']]],
#  ['Q891',
#   [['нижний', 'новгород'],
#    ['горький'],
#    ['карман', 'россия'],
#    ['столица', 'поволжье'],
#    ['нижний']]],
#  ['Q898', ['омск']],
#  ['Q899', ['суэцкий', 'канал']],
#  ['Q901', [['учёный'], ['научный', 'работник']]],
#  ['Q903', ['эрот', 'ала']],
#  ['Q907', ['гордон', 'фримя']],
#  ['Q912', [['мали'], ['республика', 'мали']]],
#  ['Q916', [['ангола'], ['республика', 'ангола']]],
#  ['Q922', ['брач']],
#  ['Q943', [['жёлтый'], ['жёлтый', 'цвета']]],
#  ['Q946', [['дональд', 'тускнуть'], ['дональд', 'францишек', 'тускнуть']]],
#  ['Q951', ['ориентирование', 'туалетный', 'бумага']],
#  ['Q952', ['реджоть']],
#  ['Q957', ['список', 'список', 'список']]]

# %% [markdown]
# Данный список списков, в котором вложеннный список - это номер Q и список списков возможных наименований сущностей, удобен нам для создания системы словарей.
# Теперь нормализуем все данные:

# %%
# %%time
norm_data = normalize(clean_data)
# Out:
# CPU times: user 43min 3s, sys: 1min 56s, total: 44min 59s
# Wall time: 47min 19s

# %%
norm_data[-100:]
# Out:
# [['Q61750033', ['ипполит', 'д’эст']],
#  ['Q61750293', ['афанасий', 'череповецкий']],
#  ['Q61750550', ['нецианин']],
#  ['Q61750774', ['лукас', 'альварес']],
#  ['Q61750983', ['жилетта', 'де', 'тренела']],
#  ['Q61750985', ['адель', 'де', 'маринья']],
#  ['Q61750996', ['бернар', 'iii', 'де', 'сен-валери']],
#  ['Q61751027', ['афанасий', 'иван', 'милославский']],
#  ['Q61751238', ['свердлов', 'юрий']],
#  ['Q61754031', ['галаксиј']],
#  ['Q61754323', ['джулия', 'коук']],
#  ['Q61754326', ['уолтер', 'плиделла-бовери']],
#  ['Q61754328', ['фицгерберт', 'райт']],
#  ['Q61754377', ['элджернон', 'фрэнсис', 'холфорд', 'фергюсон']],
#  ['Q61754382', ['джон', 'стифенсон', 'фергюсон']],
#  ['Q61754407', ['nn', 'фёдор']],
#  ['Q61754415', ['михаил', 'давыд', 'моложский']],
#  ['Q61755109',
#   [['никон', 'валерий', 'владимир'], ['валерий', 'владимир', 'никон']]],
#  ['Q61759346', ['микаэль', 'конда']],
#  ['Q61762916',
#   ['список',
#    'город',
#    'стать',
#    'столица',
#    'государство',
#    'после',
#    '1960',
#    'год']],
#  ['Q61763420', ['финал', 'кубок', 'россия', 'ростелеком', '2018-2019']],
#  ['Q61764017', ['порфиріть']],
#  ['Q61764067', ['анна', 'егор', 'щетинин']],
#  ['Q61764105', ['сергей', 'фёдор', 'волконский']],
#  ['Q61764107', ['мария', 'дмитрий', 'чаадаев']],
#  ['Q61764189', ['прасковья', 'иван', 'одоевский', 'толстой']],
#  ['Q61764419', ['гуго', 'i', 'де', 'клермона']],
#  ['Q61764420', ['маргарита', 'де', 'рамерупт']],
#  ['Q61767218', ['макаренко', 'павел', 'николай']],
#  ['Q61770912', ['по', 'вкус']],
#  ['Q61775215', ['тур', 'воклюз', '1955']],
#  ['Q61775288', ['василиса', 'иван', 'клецкай']],
#  ['Q61775303', ['тур', 'воклюз', '1977']],
#  ['Q61775322', ['тур', 'воклюз', '1986']],
#  ['Q61775325', ['тур', 'воклюз', '1989']],
#  ['Q61775333', ['тур', 'воклюз', '1995']],
#  ['Q61777426', ['мария', 'энрикес', 'де', 'киньонес-и-коссинес']],
#  ['Q61777433', ['леонора', 'манрик', 'де', 'лара']],
#  ['Q61780883', [['леонард'], ['лео'], ['лёня']]],
#  ['Q61787642', ['спортивный', 'агентство']],
#  ['Q61790423', ['никос', 'апергис']],
#  ['Q61791415',
#   [['фабрицио', 'колонна'], ['колонна', 'фабрицио', '1557–1580']]],
#  ['Q61792003', ['18-тысячная', 'статья', 'в', 'русский', 'викиновость']],
#  ['Q61807212', ['аделиза', 'де', 'тоснуть']],
#  ['Q61807852', ['эвелина', 'де', 'крепон']],
#  ['Q61809527', ['юлиан', 'иван']],
#  ['Q61810942', ['ансер', 'павел', 'александр']],
#  ['Q61811296',
#   ['донья',
#    'мария',
#    'де',
#    'ласа',
#    'мерседес',
#    'де',
#    'зорноз',
#    'и',
#    'понс',
#    'де',
#    'леон']],
#  ['Q61812126', [['салцман', 'ханс'], ['ханс', 'салцман']]],
#  ['Q61812443', ['иоганн', 'георг', 'фон', 'шёнайх-каролат']],
#  ['Q61812452', ['ванда', 'фон', 'шёнайх-каролат']],
#  ['Q61813137', ['берн', 'женева', '1919']],
#  ['Q61813139', ['берн', 'женева', '1923']],
#  ['Q61813364', ['фрэнсис', 'торнхёрстый']],
#  ['Q61813813', ['теодор', 'александр']],
#  ['Q61813856', ['поликсен', 'лимбург-штирум']],
#  ['Q61813880',
#   ['каролина', 'юлиан', 'софия', 'гогенлоэ-вальденбург-шиллингсфюрстый']],
#  ['Q61813913', ['леопольдина', 'аренберг']],
#  ['Q61813935', ['леопольд', 'иоганн']],
#  ['Q61814166', ['луиз-маргарит', 'де', 'ламарк']],
#  ['Q61819535',
#   [['родриго', 'песоль'],
#    ['родриго', 'пецоля'],
#    ['родриго', 'себастьян', 'песоль'],
#    ['родриго', 'себастьян', 'пецоля']]],
#  ['Q61823111', ['рейла']],
#  ['Q61835951', [['шавить', 'принци'], ['акаки', 'бабунашвили']]],
#  ['Q61849914',
#   ['здание', 'больница', 'на', 'улица', 'щетинкина', 'новосибирск']],
#  ['Q61856733', ['сущинский', 'пётр', 'пётр', 'фармаколог']],
#  ['Q61857950', ['финский', 'совместный', 'училище', 'выборг']],
#  ['Q61858378', ['сухановский', 'волость']],
#  ['Q61865650', ['беатрис', 'де', 'фосинья']],
#  ['Q61865807', ['виллибирга', 'фон', 'ахайма']],
#  ['Q61865819', ['гизела', 'лотарингский']],
#  ['Q61866195', ['александр', 'ii', 'десмие']],
#  ['Q61866212', ['марь', 'бадоун']],
#  ['Q61866450', ['эльжбета', 'гальшка', 'друцкий-соколинский']],
#  ['Q61866456',
#   [['юрий', 'друцкий-соколинский'], ['юрий', 'павло', 'друцкий-соколинский']]],
#  ['Q61866599', ['год', 'культура']],
#  ['Q61866637',
#   ['международный',
#    'язык',
#    'заменгоф)/полный',
#    'учебник',
#    'интернациональный',
#    'язык']],
#  ['Q61866777', [['сосенко'], ['сосенко']]],
#  ['Q61866996', ['катаржина', 'тарновский']],
#  ['Q61867000', ['екатерина']],
#  ['Q61867005', ['барбара']],
#  ['Q61867132', ['феодосий', 'рязанский']],
#  ['Q61867235', ['отия', 'микеладзе']],
#  ['Q61870067', ['артур', 'де', 'толедо']],
#  ['Q61870072', ['элиса', 'норес', 'соарес']],
#  ['Q61870683', ['александр', 'николай', 'репнина']],
#  ['Q61871317', ['кристина', 'луиз', 'нассау-идштейнский']],
#  ['Q61872068', ['тур', 'германия', '1939', 'этап', '1']],
#  ['Q61872072', ['тур', 'германия', '1939', 'этап', '5']],
#  ['Q61872085', ['тур', 'германия', '1939', 'этап', '17a']],
#  ['Q61872111', ['тур', 'германия', '1939', 'этап', '18']],
#  ['Q61872188', ['премьер-министр', 'ссср']],
#  ['Q61874269',
#   [['андрей', 'семён', 'друцкий-соколинский'],
#    ['андрей', 'семён', 'бабичев-соколинский']]],
#  ['Q61874925', ['ирена', 'боклинкэ']],
#  ['Q61881708', ['ясь', 'казимир', 'антоно']],
#  ['Q61881884', ['янчин', 'иван', 'василий']],
#  ['Q61889411', ['елизавета']],
#  ['Q61889711',
#   [['терехово'],
#    ['терехово', 'валдайский', 'район'],
#    ['терехово', 'новгородский', 'область']]],
#  ['Q61889793', ['травниковый', 'александр', 'владимир']],
#  ['Q61889805', ['фонд', 'президентский', 'грант']],
#  ['Q61890030', ['тур', 'германия', '1938', 'этап', '15']]]

# %% [markdown]
# ## Теперь о том, как будут создаваться словари.
#
# Допустим, у нас будет всего 7 словарей:
# 1. Словарь униграмм, где ключом будет униграмма, а значением - номер Q.
# 2. Словарь биграмм, где ключом будет биграмма, а значением - номер Q.
# 3. Словарь триграмм.
# 4. Словарь тетраграмм.
# 5. Словарь пентаграмм.
# 6. На всякий случай: Общий обратный словарь, где ключ - это номер сущности Q, а значения - это все возможные наименования этой сущности в нашей системе словарей. Возможно, он пригодится (например, для контроля того, как нарезаются наши сущности).
# 7. На всякий случай: Словарь дат, где ключ - это сущность, в которой встречается слово "год" и 4 цифры, а значение - это номер Q. Это будет дополнительный словарь, он может дублировать часть ключей словарей n-грамм.
#
#
# Наша функция должна проходиться по чистому нормализованному датасету Викиданных и делать следующее:
#
# 1. Создать общий обратный словарь, где номер Q - ключ, значения пока оставим пустыми.
# 2. Проверять длину каждого наименования сущности в каждой строке данных.
# - если это сущность длины 1, сразу кладем ее в словарь униграмм. Если такая сущность в словаре уже есть, прибавляем новый номер Q к сущности. То есть, одной сущности в словаре может соответствовать несколько номеров Q.
# - если это сущность длины 2, кладем ее в словарь биграмм, потом меняем элементы местами и снова кладем ее в словарь биграмм. Опять же добавляем номера Q, если вдруг ключи повторяются (на последующих этапах то же самое).
# - если это сущность длины 3, кладем ее в словарь триграмм. Также комбинаторно меняем слова сущности местами и кладем в словарь триграмм с другим ключом. А еще комбинаторно выбираем биграммы из триграмм и кладем в словарь биграмм. Это может быть полезно в случае имен собственных.
# - если это сущность длины 4, кладем ее в словарь тетраграмм, а также ее комбинаторные варианты. Также разбиваем (уже не комбинаторно) сущность на триграммы по порядку (1-2-3 слово, 2-3-4 слово) и кладем эти триграммы в словарь триграмм.
# - если это сущность длины 5, кладем ее в словарь пентаграмм, а также ее комбинаторные варианты. Также разбиваем сущность по порядку на триграммы и тетраграммы и кладем в соответствующие словари.
# - если в сущности есть слово "год" и 4 цифры, кладем ее целиком в качестве ключа в словарь дат.
# 3. После того, как мы положили что-то в один из словарей, сразу добавляем это наименование сущности (или ее часть) в обратный словарь.
# 4. Функция должна вернуть 7 словарей соответственно.
#
# Возможно, стоит разбить эту программу на более маленькие части - например, создавать эти словари постепенно.
