# %%
import requests
import pandas as pd
from collections import OrderedDict

#здесь 3 запроса SPARQL к Викиданным, которые выдают список списков с высказываниями с датами. 
#один общий запрос, скорее всего, невозможен, поскольку одной строке в табличке (=одному высказыванию) 
#может соответствовать только одна дата (или две - если это дата начала и дата окончания чего-то).
#если в одном высказывании будет много дат, то будет трудно разобраться, что к чему


#http://tinyurl.com/y9m738lr  - простые триплеты с датой
def query_for_simple_triplets(q_numbers):
    
    url = "https://query.wikidata.org/sparql"
    
    query = """SELECT ?itemLabel ?propertyLabel ?date
    WHERE
    {
      VALUES (?item) {(wd:Q???)}
  
      # ?item ?predicate ?date. 
      FILTER(DATATYPE(?date) = xsd:dateTime).
      MINUS { ?item schema:dateModified ?date. }
      MINUS { ?item wikibase:timestamp ?date. }
  
      BIND( IRI(REPLACE( STR(?predicate),"prop/direct/","entity/" )) AS ?property). 
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ru". }
    }
    ORDER BY ?item ?date
    """
        
    query = query.replace('(wd:Q???)',q_numbers)
    r = requests.get(url, params = {'format': 'json', 'query': query})
    data = r.json()
    
    lst = []
    if data != None:
        for item in data['results']['bindings']:
            lst.append([item['itemLabel']['value'], 
                        item['propertyLabel']['value'], 
                        str(item['date']['value'])[:-10]]) #"обрезание" даты. потом вставлю регулярку
    return lst


#http://tinyurl.com/yboysd2z  - start time-end time
def query_for_starttime_endtime(q_numbers):
    
    url = "https://query.wikidata.org/sparql"
    
    query = """SELECT ?itemLabel ?propertyLabel ?objectLabel ?organizationLabel ?starttime 
    # ?endtime
    WHERE {
      VALUES (?item) {(wd:Q???)}
  
      # ?item ?predicate ?statement .  
      # ?statement ?ps ?object. 
      OPTIONAL {?statement pq:P642 ?organization}.
      # ?statement pq:P580 ?starttime.
      OPTIONAL {?statement pq:P582 ?endtime}. 
   
      # ?property wikibase:statementProperty ?ps .
  
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ru" }
    }
    ORDER BY ?itemLabel ?propertyLabel
    """
    
    query = query.replace('(wd:Q???)',q_numbers)
    r = requests.get(url, params = {'format': 'json', 'query': query})
    data = r.json()
    
    lst = []
    for item in data['results']['bindings']:    
        lst.append([item['itemLabel']['value'], 
                    item['propertyLabel']['value'],
                    item['objectLabel']['value'],
                    item['organizationLabel']['value'] if 'organizationLabel' in item else '',
                    str(item['starttime']['value'])[:-10],
                    str(item['endtime']['value'])[:-10]] if 'endtime' in item else '')

    return lst


#http://tinyurl.com/y947qncg  -　point in time
def query_for_point_in_time(q_numbers):
    
    url = "https://query.wikidata.org/sparql"
    
    query = """SELECT ?itemLabel ?propertyLabel ?objectLabel ?organizationLabel ?point_in_time
    WHERE {
      VALUES (?item) {(wd:Q???)}
  
      # ?item ?predicate ?statement .  
      # ?statement ?ps ?object. 
      OPTIONAL {?statement pq:P642 ?organization}.
      # ?statement pq:P585 ?point_in_time.
   
      # ?property wikibase:statementProperty ?ps .
  
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ru" }
    }
    ORDER BY ?itemLabel ?propertyLabel
    """
    
    query = query.replace('(wd:Q???)',q_numbers)
    r = requests.get(url, params = {'format': 'json', 'query': query})
    data = r.json()
    
    lst = []
    for item in data['results']['bindings']:    
        lst.append([item['itemLabel']['value'], 
                    item['propertyLabel']['value'],
                    item['objectLabel']['value'],
                    item['organizationLabel']['value'] if 'organizationLabel' in item else '',
                    str(item['point_in_time']['value'])[:-10]])

    return lst

q_numbers = '(wd:Q635)(wd:Q656)(wd:Q243)'#здесь должны быть номера объектов из наших n-грамм
#в Викиданных, которые мы подставляем в запрос

dates_list = query_for_simple_triplets(q_numbers) + query_for_starttime_endtime(q_numbers) + query_for_point_in_time(q_numbers)
for i in dates_list:
    if i != '':
        print(i)
# Out:
# ['Эйфелева башня', 'дата основания/создания/возникновения', '1887-01-01']
# ['Эйфелева башня', 'дата официального открытия', '1889-03-31']
# ['Эйфелева башня', 'дата перехода в общественное достояние', '1993-01-01']
# ['Клеопатра', 'дата рождения', '-068-01-01']
# ['Клеопатра', 'дата смерти', '-029-08-10']
# ['Санкт-Петербург', 'дата основания/создания/возникновения', '1703-05-27']
# ['Клеопатра', 'супруг(а)', 'Птолемей XIII Теос Филопатор', '', '-050-01-01', '-046-01-01']
# ['Клеопатра', 'супруг(а)', 'Марк Антоний', '', '-036-01-01', '-029-01-01']
# ['Клеопатра', 'супруг(а)', 'Птолемей XIV', '', '-046-01-01', '-043-01-01']
# ['Санкт-Петербург', 'административно-территориальная единица', 'Российская империя', '', '1721-01-01', '1917-09-01']
# ['Санкт-Петербург', 'административно-территориальная единица', 'Российская Советская Федеративная Социалистическая Республика', '', '1922-12-30', '1991-12-25']
# ['Санкт-Петербург', 'административно-территориальная единица', 'Российская республика', '', '1917-09-01', '1917-11-07']
# ['Санкт-Петербург', 'административно-территориальная единица', 'РСФСР (1917—1922)', '', '1917-11-07', '1922-12-30']
# ['Санкт-Петербург', 'глава правительства', 'Георгий Сергеевич Полтавченко', '', '2011-01-01', '2018-01-01']
# ['Санкт-Петербург', 'глава правительства', 'Валентина Ивановна Матвиенко', '', '2003-01-01', '2011-01-01']
# ['Санкт-Петербург', 'глава правительства', 'Анатолий Александрович Собчак', '', '1991-01-01', '1996-01-01']
# ['Санкт-Петербург', 'глава правительства', 'Владимир Анатольевич Яковлев', '', '1996-01-01', '2003-01-01']
# ['Санкт-Петербург', 'город-побратим', 'Милан', '', '1967-10-02', '2012-11-22']
# ['Санкт-Петербург', 'государство', 'СССР', '', '1922-12-30', '1991-12-25']
# ['Санкт-Петербург', 'государство', 'Русское царство', '', '1703-05-27', '1721-09-10']
# ['Санкт-Петербург', 'государство', 'Российская республика', '', '1917-09-14', '1917-11-08']
# ['Санкт-Петербург', 'государство', 'Российская империя', '', '1721-09-10', '1917-11-07']
# ['Санкт-Петербург', 'государство', 'РСФСР (1917—1922)', '', '1917-11-07', '1922-12-30']
# ['Санкт-Петербург', 'названо в честь', 'Владимир Ильич Ленин', '', '1924-01-26', '1991-09-06']
# ['Санкт-Петербург', 'официальное название', 'Санкт-Петербург', '', '1703-05-27', '1914-09-12']
# ['Санкт-Петербург', 'официальное название', 'Ленінград', '', '1924-01-26', '1991-09-05']
# ['Санкт-Петербург', 'официальное название', 'Ленінград', '', '1924-01-26', '1991-09-05']
# ['Санкт-Петербург', 'официальное название', 'Ленинград', '', '1924-01-26', '1991-09-06']
# ['Санкт-Петербург', 'официальное название', 'Sankt Petersburg', '', '1703-05-27', '1914-09-12']
# ['Санкт-Петербург', 'официальное название', 'Ленінград', '', '1924-01-26', '1991-09-05']
# ['Санкт-Петербург', 'официальное название', 'Leningrád', '', '1924-01-26', '1991-09-05']
# ['Санкт-Петербург', 'официальное название', 'Sankt Petersburg', '', '1703-05-27', '1914-09-12']
# ['Санкт-Петербург', 'официальное название', 'Leningrad', '', '1924-01-26', '1991-09-05']
# ['Санкт-Петербург', 'официальное название', 'Leningrad', '', '1924-01-26', '1991-09-05']
# ['Санкт-Петербург', 'официальное название', 'Petrográd', '', '1914-09-13', '1924-01-25']
# ['Санкт-Петербург', 'официальное название', 'Petrograd', '', '1914-09-13', '1924-01-25']
# ['Санкт-Петербург', 'официальное название', 'Szentpétervár', '', '1703-05-27', '1914-09-12']
# ['Санкт-Петербург', 'официальное название', 'Петраград', '', '1914-09-13', '1924-01-25']
# ['Санкт-Петербург', 'официальное название', 'Petrograd', '', '1914-09-13', '1924-01-25']
# ['Санкт-Петербург', 'официальное название', 'Петроград', '', '1914-09-13', '1924-01-25']
# ['Санкт-Петербург', 'официальное название', 'Петраград', '', '1914-09-13', '1924-01-25']
# ['Санкт-Петербург', 'официальное название', 'Leningrado', '', '1924-01-26', '1991-09-05']
# ['Санкт-Петербург', 'предыдущее по порядку', 'Ленинград', '', '1924-01-26', '1991-09-06']
# ['Санкт-Петербург', 'это частный случай понятия', 'второй по величине город', 'СССР', '1922-01-01', '1991-01-01']
# ['Санкт-Петербург', 'это частный случай понятия', 'город-миллионер', '', '1923-01-01', '1942-01-01']
# ['Санкт-Петербург', 'это частный случай понятия', 'город-миллионер', '', '1891-01-01', '1918-01-01']
# ['Санкт-Петербург', 'это частный случай понятия', 'первый по величине город', 'Российская империя', '1800-01-01', '1917-01-01']
# ['Санкт-Петербург', 'это частный случай понятия', 'столица России', '', '1712-01-01', '1918-03-11']
# ['Санкт-Петербург', 'является столицей', 'Российская империя', '', '1730-01-01', '1917-01-01']
# ['Санкт-Петербург', 'является столицей', 'Санкт-Петербургская губерния', '', '1710-01-01', '1927-01-01']
# ['Санкт-Петербург', 'является столицей', 'Российская Советская Федеративная Социалистическая Республика', '', '1917-11-07', '1918-03-11']
# ['Санкт-Петербург', 'является столицей', 'РСФСР (1917—1922)', '', '1917-11-07', '1918-03-11']
# ['Санкт-Петербург', 'является столицей', 'Санкт-Петербургский уезд', '', '1727-01-01', '1927-01-01']
# ['Санкт-Петербург', 'является столицей', 'Ингерманландская губерния', '', '1703-01-01', '1710-01-01']
# ['Санкт-Петербург', 'является столицей', 'Российская республика', '', '1917-09-01', '1917-11-07']
# ['Санкт-Петербург', 'является столицей', 'Российская империя', '', '1721-01-01', '1728-01-01']
# ['Санкт-Петербург', 'является столицей', 'Русское царство', '', '1712-01-01', '1721-01-01']
# ['Санкт-Петербург', 'является столицей', 'Санкт-Петербургская провинция', '', '1719-01-01', '1744-01-01']
# ['Санкт-Петербург', 'полученные награды', 'город-герой', '', '1945-01-01']
# ['Санкт-Петербург', 'численность населения', '1920000', '', '1947-01-01']
# ['Санкт-Петербург', 'численность населения', '2797000', '', '1955-01-01']
# ['Санкт-Петербург', 'численность населения', '2009500', '', '1930-01-01']
# ['Санкт-Петербург', 'численность населения', '2218000', '', '1949-01-01']
# ['Санкт-Петербург', 'численность населения', '4899344', '', '2011-01-01']
# ['Санкт-Петербург', 'численность населения', '149700', '', '1764-01-01']
# ['Санкт-Петербург', 'численность населения', '217900', '', '1789-01-01']
# ['Санкт-Петербург', 'численность населения', '1688300', '', '1928-01-01']
# ['Санкт-Петербург', 'численность населения', '1541000', '', '1946-01-01']
# ['Санкт-Петербург', 'численность населения', '4882200', '', '1986-01-01']
# ['Санкт-Петербург', 'численность населения', '2300000', '', '1917-01-01']
# ['Санкт-Петербург', 'численность населения', '2314500', '', '1915-01-01']
# ['Санкт-Петербург', 'численность населения', '2118500', '', '1914-01-01']
# ['Санкт-Петербург', 'численность населения', '424700', '', '1825-01-01']
# ['Санкт-Петербург', 'численность населения', '4600000', '', '2005-01-01']
# ['Санкт-Петербург', 'численность населения', '900000', '', '1919-01-01']
# ['Санкт-Петербург', 'численность населения', '4881563', '', '1993-01-01']
# ['Санкт-Петербург', 'численность населения', '4942891', '', '1993-01-01']
# ['Санкт-Петербург', 'численность населения', '174800', '', '1780-01-01']
# ['Санкт-Петербург', 'численность населения', '927000', '', '1945-01-01']
# ['Санкт-Петербург', 'численность населения', '4661219', '', '2002-01-01']
# ['Санкт-Петербург', 'численность населения', '4588183', '', '1979-01-01']
# ['Санкт-Петербург', 'численность населения', '2992000', '', '1941-01-01']
# ['Санкт-Петербург', 'численность населения', '2814000', '', '1956-01-01']
# ['Санкт-Петербург', 'численность населения', '1469000', '', '1918-01-01']
# ['Санкт-Петербург', 'численность населения', '1281108', '', '1903-01-01']
# ['Санкт-Петербург', 'численность населения', '3296000', '', '1967-01-01']
# ['Санкт-Петербург', 'численность населения', '4762100', '', '1983-01-01']
# ['Санкт-Петербург', 'численность населения', '5131942', '', '2014-01-01']
# ['Санкт-Петербург', 'численность населения', '622000', '', '1943-01-01']
# ['Санкт-Петербург', 'численность населения', '4986900', '', '1988-01-01']
# ['Санкт-Петербург', 'численность населения', '960000', '', '1922-01-01']
# ['Санкт-Петербург', 'численность населения', '4624083', '', '2004-01-01']
# ['Санкт-Петербург', 'численность населения', '487300', '', '1850-01-01']
# ['Санкт-Петербург', 'численность населения', '4845407', '', '1995-01-01']
# ['Санкт-Петербург', 'численность населения', '1418000', '', '1900-01-01']
# ['Санкт-Петербург', 'численность населения', '4770897', '', '1999-01-01']
# ['Санкт-Петербург', 'численность населения', '4568047', '', '2008-01-01']
# ['Санкт-Петербург', 'численность населения', '740000', '', '1920-01-01']
# ['Санкт-Петербург', 'численность населения', '2258000', '', '1950-01-01']
# ['Санкт-Петербург', 'численность населения', '1905600', '', '1910-01-01']
# ['Санкт-Петербург', 'численность населения', '1033600', '', '1891-01-01']
# ['Санкт-Петербург', 'численность населения', '1379000', '', '1925-01-01']
# ['Санкт-Петербург', 'численность населения', '3915000', '', '1976-01-01']
# ['Санкт-Петербург', 'численность населения', '4635200', '', '1980-01-01']
# ['Санкт-Петербург', 'численность населения', '2920000', '', '1940-01-01']
# ['Санкт-Петербург', 'численность населения', '668000', '', '1870-01-01']
# ['Санкт-Петербург', 'численность населения', '4931200', '', '1987-01-01']
# ['Санкт-Петербург', 'численность населения', '3036000', '', '1962-01-01']
# ['Санкт-Петербург', 'численность населения', '5281579', '', '2017-01-01']
# ['Санкт-Петербург', 'численность населения', '1221000', '', '1924-01-01']
# ['Санкт-Петербург', 'численность населения', '532200', '', '1852-01-01']
# ['Санкт-Петербург', 'численность населения', '4656474', '', '2003-01-01']
# ['Санкт-Петербург', 'численность населения', '4714844', '', '2001-01-01']
# ['Санкт-Петербург', 'численность населения', '442900', '', '1833-01-01']
# ['Санкт-Петербург', 'численность населения', '4806641', '', '1997-01-01']
# ['Санкт-Петербург', 'численность населения', '4879566', '', '2010-01-01']
# ['Санкт-Петербург', 'численность населения', '150300', '', '1765-01-01']
# ['Санкт-Петербург', 'численность населения', '4741923', '', '2000-01-01']
# ['Санкт-Петербург', 'численность населения', '5028000', '', '2013-01-01']
# ['Санкт-Петербург', 'численность населения', '5007469', '', '1991-01-01']
# ['Санкт-Петербург', 'численность населения', '928000', '', '1882-01-01']
# ['Санкт-Петербург', 'численность населения', '4711200', '', '1982-01-01']
# ['Санкт-Петербург', 'численность населения', '335600', '', '1811-01-01']
# ['Санкт-Петербург', 'численность населения', '2432000', '', '1942-01-01']
# ['Санкт-Петербург', 'численность населения', '830000', '', '1921-01-01']
# ['Санкт-Петербург', 'численность населения', '3432000', '', '1960-01-01']
# ['Санкт-Петербург', 'численность населения', '4669400', '', '1981-01-01']
# ['Санкт-Петербург', 'численность населения', '468800', '', '1837-01-01']
# ['Санкт-Петербург', 'численность населения', '2415700', '', '1916-01-01']
# ['Санкт-Петербург', 'численность населения', '3949501', '', '1970-01-01']
# ['Санкт-Петербург', 'численность населения', '4581854', '', '2009-01-01']
# ['Санкт-Петербург', 'численность населения', '5225690', '', '2016-01-01']
# ['Санкт-Петербург', 'численность населения', '363900', '', '1817-01-01']
# ['Санкт-Петербург', 'численность населения', '470200', '', '1840-01-01']
# ['Санкт-Петербург', 'численность населения', '3777200', '', '1965-01-01']
# ['Санкт-Петербург', 'численность населения', '4986405', '', '1992-01-01']
# ['Санкт-Петербург', 'численность населения', '4571184', '', '2007-01-01']
# ['Санкт-Петербург', 'численность населения', '546000', '', '1944-01-01']
# ['Санкт-Петербург', 'численность населения', '3679000', '', '1973-01-01']
# ['Санкт-Петербург', 'численность населения', '4418000', '', '1975-01-01']
# ['Санкт-Петербург', 'численность населения', '5023506', '', '1989-01-01']
# ['Санкт-Петербург', 'численность населения', '4953219', '', '2012-01-01']
# ['Санкт-Петербург', 'численность населения', '2715700', '', '1935-01-01']
# ['Санкт-Петербург', 'численность населения', '1998000', '', '1948-01-01']
# ['Санкт-Петербург', 'численность населения', '4844200', '', '1985-01-01']
# ['Санкт-Петербург', 'численность населения', '539500', '', '1863-01-01']
# ['Санкт-Петербург', 'численность населения', '1590770', '', '1926-01-01']
# ['Санкт-Петербург', 'численность населения', '1439600', '', '1901-01-01']
# ['Санкт-Петербург', 'численность населения', '4806400', '', '1984-01-01']
# ['Санкт-Петербург', 'численность населения', '4820213', '', '1996-01-01']
# ['Санкт-Петербург', 'численность населения', '4580620', '', '2006-01-01']
# ['Санкт-Петербург', 'численность населения', '4783982', '', '1998-01-01']
# ['Санкт-Петербург', 'численность населения', '220200', '', '1800-01-01']
# ['Санкт-Петербург', 'численность населения', '5002444', '', '1990-01-01']
# ['Санкт-Петербург', 'численность населения', '3191304', '', '1939-01-01']
# ['Санкт-Петербург', 'численность населения', '3321196', '', '1959-01-01']
# ['Санкт-Петербург', 'численность населения', '5351935', '', '2018-01-01']
# ['Санкт-Петербург', 'численность населения', '1093000', '', '1923-01-01']

# %%
# примеры выше с Санкт-Петербургом показывают, 
# что нужно немного скорректировать запросы, чтобы было меньше лишнего 

#примерно так по году можно выбирать только релевантные высказывания:
date = '1999'
for statement in dates_list:
    if statement != '' and (statement[-1].startswith(date) or statement[-2].startswith(date)): 
        print(statement)
# Out:
# ['Санкт-Петербург', 'численность населения', '4770897', '', '1999-01-01']

# %%
#потом потестирую формат вывода датафрейм. пока обычные списки кажутся удобнее
#это результат запроса простых триплетов с датами

url = "https://query.wikidata.org/sparql"
    
query = """SELECT ?itemLabel ?propertyLabel ?date
    WHERE
    {
      VALUES (?item) {(wd:Q???)}
  
      # ?item ?predicate ?date. 
      FILTER(DATATYPE(?date) = xsd:dateTime).
      MINUS { ?item schema:dateModified ?date. }
      MINUS { ?item wikibase:timestamp ?date. }
  
      BIND( IRI(REPLACE( STR(?predicate),"prop/direct/","entity/" )) AS ?property). 
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],ru". }
    }
    ORDER BY ?item ?date
    """

q_numbers = '(wd:Q635)(wd:Q656)(wd:Q243)'
query = query.replace('(wd:Q???)',q_numbers)
r = requests.get(url, params = {'format': 'json', 'query': query})
data = r.json()

dates = []
for item in data['results']['bindings']:
    dates.append(OrderedDict({
        'item': item['itemLabel']['value'],
        'property': item['propertyLabel']['value'],
        'date': str(item['date']['value'])[:-10]})) 

df = pd.DataFrame(dates)
df.set_index('item', inplace=True)
df = df.astype({'property': str, 'date': str})
df.head(20)
# Out:
#                                                property        date
# item
# Эйфелева башня    дата основания/создания/возникновения  1887-01-01
# Эйфелева башня               дата официального открытия  1889-03-31
# Эйфелева башня   дата перехода в общественное достояние  1993-01-01
# Клеопатра                                 дата рождения  -068-01-01
# Клеопатра                                   дата смерти  -029-08-10
# Санкт-Петербург   дата основания/создания/возникновения  1703-05-27
